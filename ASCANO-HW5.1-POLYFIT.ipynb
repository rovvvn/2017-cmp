# %%
import matplotlib.pyplot as plt
import numpy as np
from math import exp as exp1

#define a function to base approximation
#f = lambda x: x * np.sin(7*x)

#generate plot with random noise using np.random.rand()
a , b = 0 , 10
n = 500

x = np.linspace(a, b, n)
y = 200*np.random.rand(n) - 100

#fit
fit = np.polyfit(x, f(x),0)
fitting1 = np.polyfit(x,y,1)
fitting2 = np.polyfit(x,y,2)
fitting3 = np.polyfit(x,y,3)
fitting4 = np.polyfit(x,y,11)
fitting1 = np.poly1d(fitting1)
fitting2 = np.poly1d(fitting2)
fitting3 = np.poly1d(fitting3)
fitting4 = np.poly1d(fitting4)

# resize
plt.figure(figsize=[20, 15])

# plot on same graph
#plt.legend(loc='lower left')
plt.plot(x, y, '*', label='noise')
#plt.plot(x, f(x), 'r', label='actual')
plt.plot(x, fitting(x), 'g', label='fit1')
plt.plot(x, fitting2(x), 'b', label='fit2')
plt.plot(x, fitting3(x), 'y', label='fit3')
plt.plot(x, fitting4(x), 'r', label='fit4')
plt.show()
