# %% [markdown]
# # HW 3 - MANDLEBROT SET
#
# This program should produce a graph that represents a fractal (Mandlebrot Set), an infinitely ramified mathematical object that contains a structure within a structure, as deep as we care to see.
#
# z' = z^2 + c
#
# where c = complex contant
#       , z = complex number
#       , z'= output and put back in equation

# %%
# Ronaldo Ascano
# due 9.19.18

# import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import math
import time
import time
from datetime import datetime, timedelta

# adjust figure, font size
plt.rcParams['figure.figsize'] = (25,20)
plt.rcParams.update({'font.size': 15})

#import urllib.request
#req = urllib.request.Request('http://www-personal.umich.edu/~mejn/cp/data/circular.txt')
#response = urllib.request.urlopen(req)
#the_page = response.read().decode()
#data = np.fromstring(the_page, dtype="float", sep=' ')
#data = np.reshape(data,[500,500])
#mandelbrot_set = np.zeros([i,j], dtype="complex")
#points = 500
#spacing = 4 / points
#mandelbrot_set = np.empty([points,points],dtype=float)

# creates module for this loop
if __name__ == "__main__":
    
    start_time = datetime.now()
    # declare plotting variables and the mandelbrot set as an empty set with NxN dimensions
    delta = 4
    points = 500
    spacing = delta / points
    mandelbrot_set = np.empty([points,points],dtype=np.float32)
    
    # create a loop within a loop to fill in the NxN array with values
    for i in range(0, points, 1):
        
        # determines pixelation vertically
        y_space = spacing * (i-points/2)
        
        for j in range(0, points, 1):
            
            # determines pixelation horizontally
            x_space = spacing * (j-points/2)
            
            # start/resets here, start w/ z=0, n counts iterations
            z = 0
            n = 0
            
            # begin while loop, runs continuously
            while True:
                
                # starting with a complex constant we start iteration (at n=0 z=c)
                z = z*z + complex(x_space,y_space)
                
                # adds 1 to n every iteration
                n += 1
                
                # once |z| is greater than or equal to 2 => add n to set
                if abs(z) >= 2:
                    mandelbrot_set[i,j] = n
                    break
                
                # if n reaches a certain # iterations, add 0 to set
                elif n == 250:
                    mandelbrot_set[i,j] = 0
                    break
                    

# shows the graph, sets the xlim and ylim w/extent, title, label axis
plt.imshow(mandelbrot_set, extent=[-2,2,-2,2], aspect='auto', cmap="hot")
plt.title('The Mandelbrot Set, (a fractal)')
plt.xlabel('x', size=10)
plt.ylabel('y', size=10)
plt.figure(dpi=100)
plt.show()

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:00:03.842391

# %%
# one way to check the OVERALL status of your program is to put them in a MODULE

help(__name__)
# Out:
# Help on module __main__:
#
# NAME
#     __main__ - Automatically created module for IPython interactive environment
#
# FUNCTIONS
#     MandelbrotPLOT(delta, points)
#
#     Mandelplot(points)
#
#     plot_results(n)
#
# DATA
#     In = ['', "# Ronaldo Ascano\n# due 9.19.18\n\n# import necessa...int('...
#     Out = {}
#     __ = ''
#     ___ = ''
#     delta = 4
#     end_time = datetime.datetime(2018, 9, 26, 13, 6, 12, 223881)
#     exit = <IPython.core.autocall.ZMQExitAutocall object>
#     func = '__main__'
#     i = 499
#     j = 499
#     mandelbrot_set = array([[1., 1., 1., ..., 1., 1., 1.],
#            [1....  ...
#     n = 1
#     points = 500
#     quit = <IPython.core.autocall.ZMQExitAutocall object>
#     spacing = 0.008
#     start_time = datetime.datetime(2018, 9, 26, 13, 6, 8, 612288)
#     x_space = 1.992
#     y_space = 1.992
#     z = (1.992+1.992j)
#
# FILE
#     (built-in)

# %%
help(plt.imshow)
# Out:
# Help on function imshow in module matplotlib.pyplot:
#
# imshow(X, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None, shape=None, filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None, hold=None, data=None, **kwargs)
#     Display an image on the axes.
#
#     Parameters
#     ----------
#     X : array_like, shape (n, m) or (n, m, 3) or (n, m, 4)
#         Display the image in `X` to current axes.  `X` may be an
#         array or a PIL image. If `X` is an array, it
#         can have the following shapes and types:
#
#         - MxN -- values to be mapped (float or int)
#         - MxNx3 -- RGB (float or uint8)
#         - MxNx4 -- RGBA (float or uint8)
#
#         MxN arrays are mapped to colors based on the `norm` (mapping
#         scalar to scalar) and the `cmap` (mapping the normed scalar to
#         a color).
#
#         Elements of RGB and RGBA arrays represent pixels of an MxN image.
# ...

# %%
# %timeit(500*500)
# Out:
# 12.1 ns ± 0.159 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
def MandelbrotPLOT(i):
    
    t1 = time.time()
    Time = []
    
    
    
    delta = 4
    points = 500
    spacing = delta / points
    mandelbrot_set = np.empty([points,points],dtype=np.float32)
    
    # create a loop within a loop to fill in the NxN array with values
    for i in range(0, points, 1):
        
        # determines pixelation vertically
        y_space = spacing * (i-points/2)
        
        for j in range(0, points, 1):
            
            # determines pixelation horizontally
            x_space = spacing * (j-points/2)
            
            # start/resets here, start w/ z=0, n counts iterations
            z = 0
            n = 0
            
            # begin while loop, runs continuously
            while True:
                
                # starting with a complex constant we start iteration (at n=0 z=c)
                z = z*z + complex(x_space,y_space)
                # adds 1 to n every iteration
                n += 1
                
                # once |z| is greater than or equal to 2 => add n to set
                if abs(z) >= 2:
                    mandelbrot_set[i,j] = n
                    t3 = time.time()
                    Time.append(t3)
                    break
                
                # if n reaches a certain # iterations, add 0 to set
                elif n == 250:
                    mandelbrot_set[i,j] = 0
                    t4 = time.time()
                    Time.append(t4)
                    break
                    
    plt.figure(1, dpi = 100)
    plt.imshow(mandelbrot_set, cmap='hot', extent=[-2,2,-2,2])
    plt.xlabel('Real')
    plt.ylabel('Imaginary')


    t2 = time.time()
    deltaT = t2 - t1
    print('Duration: ' , deltaT)
    return deltaT

# %%
MandelbrotPLOT(500)
# Out:
# Duration:  2.4407711029052734
# 2.4407711029052734

# %%
# %timeit(500*500)
# Out:
# 12.3 ns ± 0.25 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
# %timeit(100*100)
# Out:
# 11.9 ns ± 0.12 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)
